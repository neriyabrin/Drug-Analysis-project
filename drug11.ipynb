# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url="C:\\Users\\Yair\\Downloads\\Drug_Consumption.xls"
df= pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1884 entries, 0 to 1883
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1884 non-null   int64
#  1   Age        1884 non-null   object
#  2   Gender     1884 non-null   object
#  3   Education  1884 non-null   object
#  4   Country    1884 non-null   object
#  5   Ethnicity  1884 non-null   object
#  6   Nscore     1884 non-null   float64
#  7   Escore     1884 non-null   float64
#  8   Oscore     1884 non-null   float64
#  9   AScore     1884 non-null   float64
#  10  Cscore     1884 non-null   float64
#  11  Impulsive  1884 non-null   float64
#  12  SS         1884 non-null   float64
#  13  Alcohol    1884 non-null   object
#  14  Amphet     1884 non-null   object
#  15  Amyl       1884 non-null   object
#  16  Benzos     1884 non-null   object
#  17  Caff       1884 non-null   object
#  18  Cannabis   1884 non-null   object
# ...

# %%
df[['Education']].value_counts()
# Out:
# Education
# Some college or university, no certificate or degree    506
# University degree                                       480
# Masters degree                                          283
# Professional certificate/ diploma                       269
# Left school at 18 years                                 100
# Left school at 16 years                                  99
# Doctorate degree                                         89
# Left school at 17 years                                  30
# Left school before 16 years                              28
# dtype: int64

# %%
#df['Left school'] =
df.replace(['Left school at 18 years', 'Left school at 16 years', 'Left school at 17 years','Left school before 16 years'],'Left school',inplace=True)
df
# Out:
#         ID    Age Gender                                          Education  \
# 0        2  25-34      M                                   Doctorate degree
# 1        3  35-44      M                  Professional certificate/ diploma
# 2        4  18-24      F                                     Masters degree
# 3        5  35-44      F                                   Doctorate degree
# 4        6    65+      F                                        Left school
# ...    ...    ...    ...                                                ...
# 1879  1884  18-24      F  Some college or university, no certificate or ...
# 1880  1885  18-24      M  Some college or university, no certificate or ...
# 1881  1886  25-34      F                                  University degree
# 1882  1887  18-24      F  Some college or university, no certificate or ...
# 1883  1888  18-24      M  Some college or university, no certificate or ...
#
# ...

# %%
plt.figure(figsize=(10,4))
plt.xticks(rotation=70)
g = sns.countplot(data = df,x='Education')
plt.show()

# %%
df[['Age']].value_counts()
# Out:
# Age
# 18-24    643
# 25-34    481
# 35-44    355
# 45-54    294
# 55-64     93
# 65+       18
# dtype: int64

# %%
fig, axes = plt.subplots(figsize=(20,8), ncols=2)
plt.xticks(rotation=20)
for ax in axes:
    ax.tick_params(axis='x', rotation=20)
sns.boxplot(ax=axes[0], x="Education",y='Impulsive', data=df)

sns.histplot(ax=axes[1], x='Nicotine',hue="Education", data=df)

plt.show()

# %%
cl5can=df[(df.Cannabis=='CL5')|(df.Cannabis=='CL4')|(df.Cannabis=='CL6')]
df[['Can5']]=cl5can[['Cannabis']]
duca=df[(df.Education=='Doctorate degree')|(df.Education=='Left school')|(df.Education=='Some college or university, no certificate or degree')]
duc=df[(df.Education=='Some college or university, no certificate or degree')]
df[['duca1']]=duca[['Education']]
df[['duca2']]=duc[['Education']]
df
# Out:
#         ID    Age Gender                                          Education  \
# 0        2  25-34      M                                   Doctorate degree
# 1        3  35-44      M                  Professional certificate/ diploma
# 2        4  18-24      F                                     Masters degree
# 3        5  35-44      F                                   Doctorate degree
# 4        6    65+      F                                        Left school
# ...    ...    ...    ...                                                ...
# 1879  1884  18-24      F  Some college or university, no certificate or ...
# 1880  1885  18-24      M  Some college or university, no certificate or ...
# 1881  1886  25-34      F                                  University degree
# 1882  1887  18-24      F  Some college or university, no certificate or ...
# 1883  1888  18-24      M  Some college or university, no certificate or ...
#
# ...

# %%
fig, axes = plt.subplots(figsize=(20,8), ncols=2)
plt.xticks(rotation=20)
for ax in axes:
    ax.tick_params(axis='x', rotation=20)
sns.histplot(ax=axes[0], x='Age',hue='Heroin', data=df11,stat='percent')

sns.histplot(ax=axes[1], x='Age',hue="Cannabis", data=df11,stat='percent')

plt.show()

# %%
sns.regplot(data=df11, x='Heroin', y='Mushrooms')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19548\2683897655.py in <module>
# ----> 1 sns.regplot(data=df11, x='Heroin', y='Mushrooms')
#
# ~\pytun\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\pytun\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
features1=['ID','Alcohol','Amphet','Amyl','Benzos','Caff','Cannabis','Choc','Coke','Crack','Ecstasy','Heroin','Ketamine','Legalh','LSD','Meth','Mushrooms','Nicotine','Semer','VSA']
features=['ID','Education','Alcohol','Amphet','Caff','Cannabis','Choc','Heroin','LSD','Mushrooms','Nicotine','duca1','duca2']
melted_mrkt_df = pd.melt(df11[features], id_vars = 'ID', value_vars = features)
melted_mrkt_df
# Out:
#          ID   variable                                              value
# 0         2  Education                                   Doctorate degree
# 1         3  Education                  Professional certificate/ diploma
# 2         4  Education                                     Masters degree
# 3         5  Education                                   Doctorate degree
# 4         6  Education                                        Left school
# ...     ...        ...                                                ...
# 22603  1884      duca2  Some college or university, no certificate or ...
# 22604  1885      duca2  Some college or university, no certificate or ...
# 22605  1886      duca2                                                NaN
# 22606  1887      duca2  Some college or university, no certificate or ...
# 22607  1888      duca2  Some college or university, no certificate or ...
#
# [22608 rows x 3 columns]

# %%
ggg = sns.FacetGrid(data = melted_mrkt_df, col="variable",  col_wrap=4, sharex = False, sharey= False, height = 3)
ggg.map_dataframe(sns.histplot, x = 'value')
for ax in axes:
    ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19548\2031717927.py in <module>
#       2 g=pd.get_dummies(melted_mrkt_df)
#       3 plt.xticks(rotation=45)
# ----> 4 sns.scatterplot(data =g, x = 'variable', y = 'value')
#
# ~\pytun\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\pytun\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# ...

# %%
df11=df.replace(['CL0','CL1','CL2'],'not_using')
df11=df11.replace(['CL3','CL4','CL5','CL6'],'addict')
ccc=df11[(df11.Cannabis=='addict')]
df11['canab']=ccc[['Cannabis']]
hhh=df11[(df11.Heroin=='addict')]
df11['hero']=hhh[['Heroin']]
df11
# Out:
#         ID    Age Gender                                          Education  \
# 0        2  25-34      M                                   Doctorate degree
# 1        3  35-44      M                  Professional certificate/ diploma
# 2        4  18-24      F                                     Masters degree
# 3        5  35-44      F                                   Doctorate degree
# 4        6    65+      F                                        Left school
# ...    ...    ...    ...                                                ...
# 1879  1884  18-24      F  Some college or university, no certificate or ...
# 1880  1885  18-24      M  Some college or university, no certificate or ...
# 1881  1886  25-34      F                                  University degree
# 1882  1887  18-24      F  Some college or university, no certificate or ...
# 1883  1888  18-24      M  Some college or university, no certificate or ...
#
# ...

# %%
df22=df
df22['Age'].replace({'18-24':1,'25-34':2,'35-44':3,'45-54':4,'55-64':5,'65+':6},inplace=True)
temp = df22.columns
temp = temp[12:]
for i in temp:
    df22[i] = df22[i].map({'CL0':0,'CL1':1,'CL2':2,'CL3':3,'CL4':4,'CL5':5,'CL6':6})
df22
# Out:
#         ID  Age Gender                                          Education  \
# 0        2    2      M                                   Doctorate degree
# 1        3    3      M                  Professional certificate/ diploma
# 2        4    1      F                                     Masters degree
# 3        5    3      F                                   Doctorate degree
# 4        6    6      F                                        Left school
# ...    ...  ...    ...                                                ...
# 1879  1884    1      F  Some college or university, no certificate or ...
# 1880  1885    1      M  Some college or university, no certificate or ...
# 1881  1886    2      F                                  University degree
# 1882  1887    1      F  Some college or university, no certificate or ...
# 1883  1888    1      M  Some college or university, no certificate or ...
#
#                   Country Ethnicity   Nscore   Escore   Oscore   AScore  ...  \
# ...

# %%
drug_mean = []
for column in fox:
    mean = df22[column].mean()
    drug_mean.append(mean)
evrdrug={'drug':fox,'ever':drug_mean}
eve=pd.DataFrame.from_dict(evrdrug)
eve
plt.figure(figsize=(20,10))
sns.barplot(data=eve, x='drug',y='ever')
plt.show()

# %%
plt.figure(figsize=(20,10))

# %%
fox=['SS','Alcohol','Amphet','Amyl','Benzos','Caff','Cannabis','Choc','Coke','Crack','Ecstasy','Heroin','Ketamine','Legalh','LSD','Meth','Mushrooms','Nicotine','Semer','VSA']
fox1=['Age','Amphet','Amyl','Benzos','Coke','Crack','Ecstasy','Heroin','Ketamine','LSD','Meth','Mushrooms']
fox2=['Age']
corrs = df22[fox1].corr(method = 'kendall')

plt.figure(figsize=(20,10))  #figure size
sns.heatmap(data=corrs, cmap='coolwarm', annot = True)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df22, x='Age', y='Cannabis')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Cannabis'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=df22, x='Age',y='Cannabis',hue='Gender')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Cannabis'>
